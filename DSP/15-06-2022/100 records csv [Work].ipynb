# %%
import pandas as pd
df=pd.read_csv("100 records.csv")
df
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
print(df.loc[6])
# Out:
# Age                                        50
# Attrition                                 Yes
# BusinessTravel              Travel_Frequently
# DailyRate                                 647
# Department                           Hardware
# DistanceFromHome                           42
# Education                                   1
# EducationField                  Life Sciences
# EmployeeCount                               1
# EmployeeNumber                              7
# EnvironmentSatisfaction                     1
# Gender                                   Male
# HourlyRate                                140
# JobInvolvement                              1
# JobLevel                                    2
# JobRole                       Human Resources
# JobSatisfaction                             1
# MaritalStatus                         Married
# MonthlyIncome                           37387
# MonthlyRate                            373870
# ...

# %%
print(df.loc[df["Age"]>50])
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 4    54       Yes         Non-Travel        993                Software
# 7    58       Yes         Non-Travel        668  Research & Development
# 8    56        No      Travel_Rarely       1031                Software
# 19   59       Yes  Travel_Frequently        760                 Support
# 25   51        No  Travel_Frequently        444                 Support
# 31   53       Yes         Non-Travel       1363                Hardware
# 35   59       Yes  Travel_Frequently        294  Research & Development
# 42   60        No      Travel_Rarely       1076                Software
# 43   56       Yes  Travel_Frequently       1317  Research & Development
# 44   60       Yes         Non-Travel       1217  Research & Development
# 46   54        No      Travel_Rarely        431                   Sales
# 48   57       Yes      Travel_Rarely       1471                 Support
# ...

# %%
df["gender"]="f"

# %%
df
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.loc[1]
# Out:
# Age                                                26
# Attrition                                          No
# BusinessTravel                             Non-Travel
# DailyRate                                         841
# Department                                   Hardware
# DistanceFromHome                                   39
# Education                                           1
# EducationField                                Medical
# EmployeeCount                                       1
# EmployeeNumber                                      2
# EnvironmentSatisfaction                             3
# Gender                                           Male
# HourlyRate                                         79
# JobInvolvement                                      1
# JobLevel                                            1
# JobRole                     Healthcare Representative
# JobSatisfaction                                     3
# ...

# %%
df.loc[3,"OverTime"]
# Out:
# 'Yes'

# %%
df.loc[3,"EducationField"]
# Out:
# 'Human Resources'

# %%
newdf=df[(df.Age>55)&(df.DailyRate>1200)]

# %%
newdf
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 43   56       Yes  Travel_Frequently       1317  Research & Development
# 44   60       Yes         Non-Travel       1217  Research & Development
# 48   57       Yes      Travel_Rarely       1471                 Support
# 59   56       Yes      Travel_Rarely       1485                 Support
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 43                 7          4  Life Sciences              1              44
# 44                30          3          Other              1              45
# 48                10          3      Marketing              1              49
# 59                17          5  Life Sciences              1              60
#
#     ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 43  ...             80                3                 31
# 44  ...             80                4                 35
# ...

# %%
newdf["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-be1e9a0b36e7> in <module>
# ----> 1 newdf["name"]
#
# ...

# %%
df.to_excel("records.xlsx",sheet_name="s1")
a=pd.read_excel("record.xlsx")
a
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-d7079cb39081> in <module>
#       1 df.to_excel("records.xlsx",sheet_name="s1")
# ----> 2 a=pd.read_excel("record.xlsx")
#       3 a
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
# ...
