# %%
import numpy as np
import pandas as pd

# %%
ipl=pd.read_csv("IPL IMB381IPL2013.csv")

# %%
ipl.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
# k=pd.set_option("display.max_columns",4)

# %%
# print(k)

# %%
ipl.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
list(ipl.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl.head().transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B                 0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
# Sl.NO.           130 non-null int64
# PLAYER NAME      130 non-null object
# AGE              130 non-null int64
# COUNTRY          130 non-null object
# TEAM             130 non-null object
# PLAYING ROLE     130 non-null object
# T-RUNS           130 non-null int64
# T-WKTS           130 non-null int64
# ODI-RUNS-S       130 non-null int64
# ODI-SR-B         130 non-null float64
# ODI-WKTS         130 non-null int64
# ODI-SR-BL        130 non-null float64
# CAPTAINCY EXP    130 non-null int64
# RUNS-S           130 non-null int64
# HS               130 non-null int64
# AVE              130 non-null float64
# SR-B             130 non-null float64
# SIXERS           130 non-null int64
# RUNS-C           130 non-null int64
# WKTS             130 non-null int64
# AVE-BL           130 non-null float64
# ECON             130 non-null float64
# ...

# %%
ipl[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
ipl[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
ipl[["PLAYER NAME"]][0:5]
# Out:
#     PLAYER NAME
# 0   Abdulla, YA
# 1  Abdur Razzak
# 2   Agarkar, AB
# 3     Ashwin, R
# 4  Badrinath, S

# %%
ipl.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
ipl.iloc[4:9][1:4]
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 5         172     72.26  ...   95.45       0       0     0    0.00  0.00
# 6         120     78.94  ...   72.22       1    1342    52   25.81  7.98
# 7          50     92.59  ...  165.88       1     693    37   18.73  7.22
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 5   0.00          2009       50000       50000
# 6  19.40          2011      100000      500000
# 7  15.57          2011      200000      700000
#
# [3 rows x 26 columns]

# %%
ipl.COUNTRY[:]
# Out:
# 0       SA
# 1      BAN
# 2      IND
# 3      IND
# 4      IND
#       ...
# 125    IND
# 126    PAK
# 127    IND
# 128    IND
# 129     SL
# Name: COUNTRY, Length: 130, dtype: object

# %%
ipl.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# ZIM     1
# BAN     1
# Name: COUNTRY, dtype: int64

# %% [markdown]
# - Normalize function fixes the whole values in between the 0 to 1

# %%
ipl.COUNTRY.value_counts(normalize=True)
# Out:
# IND    0.407692
# AUS    0.169231
# SA     0.123077
# SL     0.092308
# PAK    0.069231
# NZ     0.053846
# WI     0.046154
# ENG    0.023077
# ZIM    0.007692
# BAN    0.007692
# Name: COUNTRY, dtype: float64

# %%
pd.crosstab(ipl.COUNTRY,ipl.AGE)
# Out:
# AGE       1   2   3
# COUNTRY
# AUS       2  10  10
# BAN       0   1   0
# ENG       0   3   0
# IND      13  35   5
# NZ        0   5   2
# PAK       0   7   2
# SA        0  11   5
# SL        1   8   3
# WI        0   5   1
# ZIM       0   1   0

# %%
ipl[['PLAYER NAME','SIXERS']].sort_values('SIXERS')[-5:]
# Out:
#       PLAYER NAME  SIXERS
# 82     Pathan, YK      81
# 97     Sharma, RG      82
# 28  Gilchrist, AC      86
# 88      Raina, SK      97
# 26      Gayle, CH     129

# %%
ipl["PREMIUM"]=ipl["SOLD PRICE"]-ipl["BASE PRICE"]

# %%
ipl[["PLAYER NAME","BASE PRICE","SOLD PRICE","PREMIUM"]][0:5]
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  PREMIUM
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %% [markdown]
# ### Which players got the maximum premium offering on their base price

# %%
ipl[["PLAYER NAME","BASE PRICE","PREMIUM"]].sort_values("PREMIUM",ascending=False)[0:5]
# Out:
#        PLAYER NAME  BASE PRICE  PREMIUM
# 50        Kohli, V      150000  1650000
# 113     Tiwary, SS      100000  1500000
# 127   Yuvraj Singh      400000  1400000
# 111  Tendulkar, SR      400000  1400000
# 93       Sehwag, V      400000  1400000

# %%
ipl.groupby("AGE")["SOLD PRICE"].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %% [markdown]
# ### Average SOLD PRICE for Different Playing Roles in Each Age Category?

# %%
x=ipl.groupby(["PLAYING ROLE","AGE"])["SOLD PRICE"].mean().reset_index()

# %%
x
# Out:
#    PLAYING ROLE  AGE    SOLD PRICE
# 0    Allrounder    1  5.875000e+05
# 1    Allrounder    2  4.494000e+05
# 2    Allrounder    3  7.666667e+05
# 3       Batsman    1  1.110000e+06
# 4       Batsman    2  6.547619e+05
# 5       Batsman    3  4.576923e+05
# 6        Bowler    1  5.177143e+05
# 7        Bowler    2  3.979310e+05
# 8        Bowler    3  4.143750e+05
# 9     W. Keeper    2  4.677273e+05
# 10    W. Keeper    3  7.000000e+05

# %%
soldprice_comparison = x.merge(x, on = "AGE", how = "outer")
soldprice_comparison
# Out:
#    PLAYING ROLE_x  AGE  SOLD PRICE_x PLAYING ROLE_y  SOLD PRICE_y
# 0      Allrounder    1  5.875000e+05     Allrounder  5.875000e+05
# 1      Allrounder    1  5.875000e+05        Batsman  1.110000e+06
# 2      Allrounder    1  5.875000e+05         Bowler  5.177143e+05
# 3         Batsman    1  1.110000e+06     Allrounder  5.875000e+05
# 4         Batsman    1  1.110000e+06        Batsman  1.110000e+06
# 5         Batsman    1  1.110000e+06         Bowler  5.177143e+05
# 6          Bowler    1  5.177143e+05     Allrounder  5.875000e+05
# 7          Bowler    1  5.177143e+05        Batsman  1.110000e+06
# 8          Bowler    1  5.177143e+05         Bowler  5.177143e+05
# 9      Allrounder    2  4.494000e+05     Allrounder  4.494000e+05
# 10     Allrounder    2  4.494000e+05        Batsman  6.547619e+05
# 11     Allrounder    2  4.494000e+05         Bowler  3.979310e+05
# 12     Allrounder    2  4.494000e+05      W. Keeper  4.677273e+05
# ...

# %% [markdown]
# ### Which players have hit more then 80 sixes in the IPL tournament so far?

# %%
ipl[ipl["SIXERS"]>80][["PLAYER NAME","SIXERS"]]
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 28  Gilchrist, AC      86
# 82     Pathan, YK      81
# 88      Raina, SK      97
# 97     Sharma, RG      82

# %%
 ipl.drop("Sl.NO.",inplace=True,axis=1)

# %%
ipl.columns
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE', 'PREMIUM'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
import warnings

# %%
sn.barplot(x="AGE",y="SOLD PRICE",data=x);

# %%
plt.hist(ipl["SOLD PRICE"]);

# %%
plt.hist(ipl["SOLD PRICE"],bins=20);

# %%
sn.distplot(ipl["SOLD PRICE"]);

# %%
box=sn.boxplot(ipl["SOLD PRICE"]);

# %%
box=plt.boxplot(ipl["SOLD PRICE"]);

# %%
ipl[ipl["SOLD PRICE"]>1350000][["PLAYER NAME","PLAYING ROLE","SOLD PRICE"]]
# Out:
#        PLAYER NAME PLAYING ROLE  SOLD PRICE
# 15       Dhoni, MS    W. Keeper     1500000
# 23     Flintoff, A   Allrounder     1550000
# 50        Kohli, V      Batsman     1800000
# 83   Pietersen, KP      Batsman     1550000
# 93       Sehwag, V      Batsman     1800000
# 111  Tendulkar, SR      Batsman     1800000
# 113     Tiwary, SS      Batsman     1600000
# 127   Yuvraj Singh      Batsman     1800000
